# %% [markdown]
# <a href="https://colab.research.google.com/github/archanaladke3/Adv/blob/master/BreakAnd_continue.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**BREAK**
#
# *   Break is used to stop the loop immediately

# %%
for i in range(1,11):
  if i==5:
    break
  print(i)
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# ##**Continue**

# %%
for i in range(1,11):
 if i==5:
  continue
 print(i)
# Out:
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9
# 10

# %%
#1.a user wants is intiating a withdrawl of given amount. check if the account has sufficent balance or not.
# if yes then>initiate the withdrawl, if not print "insufficeint balnce"

balnce=15000
if balnce>=1500:
  withdrow=5000
  balance=balnce-withdrow
  print("withrdrow","balnce:",balance)
else:
    print("insufficent amount")
# Out:
# withrdrow balnce: 10000

# %%
balance = 10000
withdrawl = int(input("enter a amount:"))
if withdrawl>balance :
  print("insufficient balance")
else : print("sufficient balance")
# Out:
# enter a amount:3000
# sufficient balance

# %%
#2.Write a function cal(a,b,c) rhat gives sum, product,difference
def cal(a,b,c):
  sum=a+b+c
  print(sum)
  product=a*b*c
  print(product)
  differnce=a-b-c
  print(differnce)
cal(3,6,8)
# Out:
# 17
# 144
# -11

# %%
#3.Write a function intro(name,class, city) and call it using keyword arguments
def intro(name,course,city):
  print("name :",name,"course :",course,"city :",city)
intro("archana","DS","pune")
# Out:
# name : archana course : DS city : pune

# %% [markdown]
# ##Keyword arg allows to ignore order while calling function

# %%
# Create two function:
#square
#Cube
# cube function should be internally
def cube(n):
  return  n*n*n

def square(no):
  sq=no*no
  print("square",sq)
  cu=cube(n)
  print("cube :",cu)

# %%
cube(3)
square(2)
# Out:
# square 4
# cube : 8

# %%
#5. Write a function bill(amount,tax) that retunrs final amount after adding tax
#tax=18%
amount=int(input("enter amount"))
tax=float(input("enter tax value"))

def amount(amount,tax):
  billamount=amount+tax
  return billamount

  amount(amount,tax)
# Out:
# enter amount1200
# enter tax value0.18

# %% [markdown]
# **#LAMDA fUNCTIONS**
#
#
# LAMBDA FUNCTIONS is short one line function

# %%
#Syntax
#Lambda pareameters:expression
#lambda:keyword
#parameter:input
# expression:logic

# %%
def sqr(x):
  return x*x

# %%
print(sq(5))
# Out:
# 25

# %%
sq=lambda x:x*x

# %%
#Write a lambda fun to add two numers
add=lambda a,b:a+b
print(add(2,4))
# Out:
# 6

# %%
#Write a lambda fun to get last character of string
last_char=lambda a:a[-1]
print(last_char("Vikas"))
# Out:
# s
