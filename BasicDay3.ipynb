# %% [markdown]
# <a href="https://colab.research.google.com/github/archanaladke3/Adv/blob/master/BasicDay3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Control Flow

# %% [markdown]
# # if condition:
# #   code to run

# %%
# if age is more than 18 print "your're an adult"
age=int(input())
if age>=18:
 print("you are adult")
else:
 print("not elegible")
# Out:
# 18
# you are adult

# %%
#take a number from user and check if its even or odd
number=int(input())
if number % 2== 0:
   print("is even")
else:
   print("is odd")
# Out:
# 45
# is odd

# %%
# check the person senior citizen or not
age1=int(input())
if age1 >=60:
  print("is senior citizen")
else:
  print("is not senior citizen")
# Out:
# 34
# is not senior citizen

# %%
# check if a number is positive or negative or zero
num=int(input())
if num>0:
   print("number is positive")
elif num<0:
  print("number is negative")
else:
  print("number is zero")
# Out:
# 0
# number is zero

# %%
#check if password is strong or weak. password is stong when is>=8 characters.if pswrd is weak ask user to reenter password.
password=input("enter passworsd")
if len(password)<8:
   print("weak password")
   password=input("enter passworsd ")
   print("strong password")
# Out:
# enter passworsdzzzzzzzzz

# %%
#categories Age
#if age less than12:child
#12_17:teenager
#18-58:adult
#60+ senior citizen
age3=int(input())
if age3<=12:
   print("chlid")
elif age3<=13:
   print("teenger")
elif age3<=18:
   print("adult")
else:
 print(" senior citzen")
# Out:
# 13
# teenger
