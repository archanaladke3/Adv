# %% [markdown]
# <a href="https://colab.research.google.com/github/archanaladke3/Adv/blob/master/basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# STRINGS

# %% [markdown]
# any sequence of characters be it letters,numbers,symbols which are enclosed in quotes is a string

# %%
name ="shubhankar"
marks="333"
marks=333

# %% [markdown]
# ##indexing

# %%
accessing data by position

# %%
print(name[0])
# Out:
# m

# %%
print(name[-1]);
# Out:
# r

# %% [markdown]
# ##slicing

# %%
slicing means taking a portion out string

# %%
print(name[0:4])
# Out:
# shub

# %%
sub="python"

# %%
print(sub[2:])
# Out:
# thon

# %% [markdown]
# ##### Basic string method
#
# a method is function that belongs to somthing for ex:a string

# %%
example=" batch two"

# %%
print(example.lower())
print(example.upper())
# Out:
#  batch two
#  BATCH TWO

# %%
from os import replace
# replace
# bye paython
word="hello python"
new_word=word.replace("hello","bye")
print(new_word);
# Out:
# bye python

# %%
# replace
a="Hello world"
b="hey world"

# %%
# stripping Extra spaces
print(example.strip())
# Out:
# batch two

# %% [markdown]
# ##len
# len is function to get length of  string

# %%
len(new_word)
# Out:
# 10

# %% [markdown]
#  create a variable of full name, print first and last charcter
#  take a string "data analysis" and replace analysis with science
#  convert the above string to title case, upper and lower case.

# %%
fullname="archana ladke"
print(fullname[0])
print(fullname[-1])
# Out:
# a
# e

# %%
a="data analysis"
new=a.replace("analysis","science")
print(new)
# Out:
# data science

# %%
print(a.lower())
print(a.upper())
print(a.title())
# Out:
# data analysis
# DATA ANALYSIS
# Data Analysis

# %% [markdown]
# LIsts
# items in ordered sequence

# %%
shopping_list=["clothes","shoes","watch","potatoes","tv"]
print(shopping_list[1]);
shopping_list.append("mobile");
print(shopping_list)
# Out:
# shoes
# ['clothes', 'shoes', 'watch', 'potatoes', 'tv', 'mobile']

# %%
shopping_list[4]="monitor"
print(shopping_list)
# Out:
# ['clothes', 'shoes', 'watch', 'potatoes', 'monitor', 'mobile']

# %%
shopping_list.insert(5,"charger")
print(shopping_list)
# Out:
# ['clothes', 'shoes', 'watch', 'potatoes', 'monitor', 'charger', 'charger', 'mobile']

# %%
shopping_list.remove("shoes");# remove the first matching value

# %%
len(shopping_list)
# Out:
# 7

# %%
list_item=shopping_list.pop()
print(list_item)
# Out:
# mobile
